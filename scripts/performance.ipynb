# %%
import csv
from subprocess import run
import os

for b in range(10, 180000, 400):
    run(['./barnes_hut_for_testing.out', f'{b}', '10', 'galactic_chaos_180k.csv', f'180ksweep_BH_intel_arc_0_5', '0.5'])
# Out:
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:01 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.321336ms
# reduction_max: 0.324250ms
# reset_init: 0.090932ms
# build: 0.258850ms
# summarize: 3.574966ms
# compute_acc: 0.376244ms
# update_vel: 0.071245ms
# update_pos: 0.069996ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:01 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.449443ms
# reduction_max: 0.450592ms
# reset_init: 0.059475ms
# build: 4.210413ms
# summarize: 2.532257ms
# compute_acc: 1.579265ms
# update_vel: 0.045723ms
# update_pos: 0.042390ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:02 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.466203ms
# reduction_max: 0.480999ms
# reset_init: 0.055621ms
# build: 9.202807ms
# summarize: 2.701205ms
# compute_acc: 1.962912ms
# update_vel: 0.045204ms
# update_pos: 0.040414ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:02 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.467351ms
# reduction_max: 0.472560ms
# reset_init: 0.055516ms
# build: 15.071247ms
# summarize: 2.594434ms
# compute_acc: 2.146871ms
# update_vel: 0.043121ms
# update_pos: 0.040308ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:02 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.485155ms
# reduction_max: 0.488378ms
# reset_init: 0.055828ms
# build: 20.897807ms
# summarize: 3.190688ms
# compute_acc: 2.261142ms
# update_vel: 0.045098ms
# update_pos: 0.041768ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:02 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.467556ms
# reduction_max: 0.473185ms
# reset_init: 0.055101ms
# build: 25.594891ms
# summarize: 2.969338ms
# compute_acc: 2.322809ms
# update_vel: 0.045204ms
# update_pos: 0.040101ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:03 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.528173ms
# reduction_max: 0.526823ms
# reset_init: 0.058746ms
# build: 30.832704ms
# summarize: 4.252050ms
# compute_acc: 2.423223ms
# update_vel: 0.046038ms
# update_pos: 0.044057ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:03 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.494100ms
# reduction_max: 0.504838ms
# reset_init: 0.055723ms
# build: 36.870830ms
# summarize: 3.571616ms
# compute_acc: 2.497496ms
# update_vel: 0.046558ms
# update_pos: 0.040619ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:03 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.522028ms
# reduction_max: 0.532337ms
# reset_init: 0.061349ms
# build: 44.290620ms
# summarize: 3.938079ms
# compute_acc: 2.709058ms
# update_vel: 0.049371ms
# update_pos: 0.043329ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:03 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.501088ms
# reduction_max: 0.508274ms
# reset_init: 0.061038ms
# build: 50.176350ms
# summarize: 4.329431ms
# compute_acc: 2.811246ms
# update_vel: 0.047078ms
# update_pos: 0.041660ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:04 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.504006ms
# reduction_max: 0.506813ms
# reset_init: 0.062705ms
# build: 53.591245ms
# summarize: 4.879329ms
# compute_acc: 2.863536ms
# update_vel: 0.046351ms
# update_pos: 0.043640ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:04 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.556923ms
# reduction_max: 0.560144ms
# reset_init: 0.065830ms
# build: 60.965828ms
# summarize: 5.320786ms
# compute_acc: 3.145933ms
# update_vel: 0.052808ms
# update_pos: 0.044475ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:04 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.580149ms
# reduction_max: 0.578484ms
# reset_init: 0.067183ms
# build: 67.024162ms
# summarize: 5.858600ms
# compute_acc: 3.305621ms
# update_vel: 0.052913ms
# update_pos: 0.046557ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:05 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.550978ms
# reduction_max: 0.561915ms
# reset_init: 0.068016ms
# build: 71.518537ms
# summarize: 6.073604ms
# compute_acc: 3.467600ms
# update_vel: 0.052183ms
# update_pos: 0.048225ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:05 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.557953ms
# reduction_max: 0.561188ms
# reset_init: 0.072079ms
# build: 76.605935ms
# summarize: 6.934326ms
# compute_acc: 4.126247ms
# update_vel: 0.056559ms
# update_pos: 0.049683ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:05 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.555881ms
# reduction_max: 0.563064ms
# reset_init: 0.077391ms
# build: 83.156766ms
# summarize: 6.621826ms
# compute_acc: 4.011141ms
# update_vel: 0.055412ms
# update_pos: 0.048850ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:06 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.545148ms
# reduction_max: 0.552030ms
# reset_init: 0.075726ms
# build: 88.038745ms
# summarize: 6.922986ms
# compute_acc: 4.324267ms
# update_vel: 0.054475ms
# update_pos: 0.049477ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:06 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.546502ms
# reduction_max: 0.550873ms
# reset_init: 0.075620ms
# build: 96.674163ms
# summarize: 7.300687ms
# compute_acc: 4.783850ms
# update_vel: 0.055204ms
# update_pos: 0.047496ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:06 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.536084ms
# reduction_max: 0.538685ms
# reset_init: 0.079682ms
# build: 100.558224ms
# summarize: 8.451940ms
# compute_acc: 5.012181ms
# update_vel: 0.054580ms
# update_pos: 0.047392ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:07 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.530038ms
# reduction_max: 0.543788ms
# reset_init: 0.078851ms
# build: 107.345411ms
# summarize: 7.944118ms
# compute_acc: 5.314578ms
# update_vel: 0.050933ms
# update_pos: 0.048640ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:07 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.563387ms
# reduction_max: 0.571717ms
# reset_init: 0.083849ms
# build: 112.495098ms
# summarize: 8.223397ms
# compute_acc: 5.636142ms
# update_vel: 0.055619ms
# update_pos: 0.051872ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:08 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.574205ms
# reduction_max: 0.586393ms
# reset_init: 0.084891ms
# build: 121.029890ms
# summarize: 7.315262ms
# compute_acc: 6.470413ms
# update_vel: 0.054371ms
# update_pos: 0.050309ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:08 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.564930ms
# reduction_max: 0.560024ms
# reset_init: 0.087703ms
# build: 126.511038ms
# summarize: 8.718920ms
# compute_acc: 6.740620ms
# update_vel: 0.053329ms
# update_pos: 0.047913ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:08 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.575760ms
# reduction_max: 0.580657ms
# reset_init: 0.088431ms
# build: 131.463539ms
# summarize: 7.917560ms
# compute_acc: 7.847077ms
# update_vel: 0.059578ms
# update_pos: 0.054996ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:09 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.617559ms
# reduction_max: 0.618698ms
# reset_init: 0.095514ms
# build: 139.100725ms
# summarize: 8.210801ms
# compute_acc: 7.192391ms
# update_vel: 0.057495ms
# update_pos: 0.053226ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:09 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.578158ms
# reduction_max: 0.579198ms
# reset_init: 0.092913ms
# build: 146.321558ms
# summarize: 7.852043ms
# compute_acc: 7.410724ms
# update_vel: 0.058123ms
# update_pos: 0.053226ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:10 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.592222ms
# reduction_max: 0.598583ms
# reset_init: 0.095517ms
# build: 151.210518ms
# summarize: 8.526310ms
# compute_acc: 8.160620ms
# update_vel: 0.060516ms
# update_pos: 0.056037ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:10 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.608802ms
# reduction_max: 0.618382ms
# reset_init: 0.101246ms
# build: 161.482809ms
# summarize: 9.293815ms
# compute_acc: 8.687495ms
# update_vel: 0.064578ms
# update_pos: 0.055725ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:11 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.586386ms
# reduction_max: 0.593265ms
# reset_init: 0.098955ms
# build: 166.211975ms
# summarize: 9.217138ms
# compute_acc: 9.264058ms
# update_vel: 0.059684ms
# update_pos: 0.056767ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:11 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.580761ms
# reduction_max: 0.586182ms
# reset_init: 0.099997ms
# build: 173.814890ms
# summarize: 8.705264ms
# compute_acc: 9.170308ms
# update_vel: 0.061036ms
# update_pos: 0.053434ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:12 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.580759ms
# reduction_max: 0.592538ms
# reset_init: 0.102913ms
# build: 181.222077ms
# summarize: 10.236929ms
# compute_acc: 9.638641ms
# update_vel: 0.063227ms
# update_pos: 0.058955ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:12 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.615764ms
# reduction_max: 0.623265ms
# reset_init: 0.111765ms
# build: 187.499890ms
# summarize: 11.971837ms
# compute_acc: 10.722079ms
# update_vel: 0.063432ms
# update_pos: 0.060519ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:13 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.615353ms
# reduction_max: 0.618367ms
# reset_init: 0.114265ms
# build: 193.348538ms
# summarize: 12.115582ms
# compute_acc: 10.567704ms
# update_vel: 0.066453ms
# update_pos: 0.059579ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:13 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.636716ms
# reduction_max: 0.643168ms
# reset_init: 0.111453ms
# build: 199.936139ms
# summarize: 11.707679ms
# compute_acc: 11.107806ms
# update_vel: 0.067285ms
# update_pos: 0.061246ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:14 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.610142ms
# reduction_max: 0.599307ms
# reset_init: 0.116559ms
# build: 208.533225ms
# summarize: 11.941414ms
# compute_acc: 11.292913ms
# update_vel: 0.064267ms
# update_pos: 0.058015ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:14 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.589815ms
# reduction_max: 0.596803ms
# reset_init: 0.111557ms
# build: 212.295203ms
# summarize: 11.511205ms
# compute_acc: 11.361037ms
# update_vel: 0.061246ms
# update_pos: 0.056975ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:15 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.582525ms
# reduction_max: 0.587946ms
# reset_init: 0.116454ms
# build: 220.259475ms
# summarize: 11.638288ms
# compute_acc: 12.552598ms
# update_vel: 0.065204ms
# update_pos: 0.059892ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:15 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.647445ms
# reduction_max: 0.651609ms
# reset_init: 0.124266ms
# build: 226.410516ms
# summarize: 11.572032ms
# compute_acc: 12.378016ms
# update_vel: 0.069475ms
# update_pos: 0.063121ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:16 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.662750ms
# reduction_max: 0.675147ms
# reset_init: 0.121664ms
# build: 234.115308ms
# summarize: 15.097880ms
# compute_acc: 13.045621ms
# update_vel: 0.072807ms
# update_pos: 0.064163ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:16 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.619623ms
# reduction_max: 0.624931ms
# reset_init: 0.122705ms
# build: 237.681142ms
# summarize: 12.480678ms
# compute_acc: 13.424788ms
# update_vel: 0.070205ms
# update_pos: 0.061869ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:17 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.600967ms
# reduction_max: 0.607531ms
# reset_init: 0.127078ms
# build: 244.949787ms
# summarize: 12.372979ms
# compute_acc: 13.615516ms
# update_vel: 0.069891ms
# update_pos: 0.061141ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:17 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.637829ms
# reduction_max: 0.638774ms
# reset_init: 0.123327ms
# build: 252.150725ms
# summarize: 11.342231ms
# compute_acc: 16.353537ms
# update_vel: 0.066350ms
# update_pos: 0.064996ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:18 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.630958ms
# reduction_max: 0.639197ms
# reset_init: 0.128017ms
# build: 258.267600ms
# summarize: 11.946828ms
# compute_acc: 19.041871ms
# update_vel: 0.071663ms
# update_pos: 0.064163ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:18 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.652327ms
# reduction_max: 0.653999ms
# reset_init: 0.130203ms
# build: 266.402809ms
# summarize: 15.197769ms
# compute_acc: 18.344578ms
# update_vel: 0.070725ms
# update_pos: 0.064579ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:19 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.630131ms
# reduction_max: 0.629084ms
# reset_init: 0.132704ms
# build: 272.305100ms
# summarize: 14.198920ms
# compute_acc: 19.881976ms
# update_vel: 0.072288ms
# update_pos: 0.066871ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:20 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.692752ms
# reduction_max: 0.705253ms
# reset_init: 0.138536ms
# build: 282.139057ms
# summarize: 14.657151ms
# compute_acc: 21.697182ms
# update_vel: 0.079681ms
# update_pos: 0.068954ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:20 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.634708ms
# reduction_max: 0.642005ms
# reset_init: 0.134372ms
# build: 288.128954ms
# summarize: 13.589224ms
# compute_acc: 21.165413ms
# update_vel: 0.076350ms
# update_pos: 0.065517ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:21 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.645340ms
# reduction_max: 0.653366ms
# reset_init: 0.138222ms
# build: 291.424057ms
# summarize: 16.614021ms
# compute_acc: 21.929683ms
# update_vel: 0.075412ms
# update_pos: 0.068433ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:21 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.643982ms
# reduction_max: 0.644408ms
# reset_init: 0.138016ms
# build: 299.322079ms
# summarize: 16.128813ms
# compute_acc: 22.802807ms
# update_vel: 0.074475ms
# update_pos: 0.066453ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:22 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.646171ms
# reduction_max: 0.641692ms
# reset_init: 0.137703ms
# build: 302.673017ms
# summarize: 16.212347ms
# compute_acc: 22.796038ms
# update_vel: 0.075308ms
# update_pos: 0.069684ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:23 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.638980ms
# reduction_max: 0.652213ms
# reset_init: 0.141349ms
# build: 309.576351ms
# summarize: 16.033602ms
# compute_acc: 22.753641ms
# update_vel: 0.075829ms
# update_pos: 0.067390ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:23 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.703380ms
# reduction_max: 0.707019ms
# reset_init: 0.147288ms
# build: 316.068119ms
# summarize: 16.942982ms
# compute_acc: 23.433538ms
# update_vel: 0.080306ms
# update_pos: 0.073224ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:24 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.646593ms
# reduction_max: 0.648370ms
# reset_init: 0.144580ms
# build: 323.216871ms
# summarize: 16.075794ms
# compute_acc: 25.300307ms
# update_vel: 0.077600ms
# update_pos: 0.071246ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:25 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.679402ms
# reduction_max: 0.675444ms
# reset_init: 0.150517ms
# build: 335.698640ms
# summarize: 15.897884ms
# compute_acc: 24.205934ms
# update_vel: 0.092184ms
# update_pos: 0.077600ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:25 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.701804ms
# reduction_max: 0.704090ms
# reset_init: 0.154370ms
# build: 340.817392ms
# summarize: 17.628292ms
# compute_acc: 23.844162ms
# update_vel: 0.090307ms
# update_pos: 0.080308ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:26 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.703066ms
# reduction_max: 0.709839ms
# reset_init: 0.157184ms
# build: 347.284996ms
# summarize: 15.910169ms
# compute_acc: 25.508122ms
# update_vel: 0.087392ms
# update_pos: 0.082080ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:27 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.730343ms
# reduction_max: 0.743786ms
# reset_init: 0.157079ms
# build: 355.453120ms
# summarize: 20.452251ms
# compute_acc: 24.612810ms
# update_vel: 0.109266ms
# update_pos: 0.093121ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:27 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.693775ms
# reduction_max: 0.697527ms
# reset_init: 0.161141ms
# build: 362.173955ms
# summarize: 20.536831ms
# compute_acc: 24.983433ms
# update_vel: 0.084892ms
# update_pos: 0.081246ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:28 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.686280ms
# reduction_max: 0.687419ms
# reset_init: 0.159370ms
# build: 366.216974ms
# summarize: 19.317765ms
# compute_acc: 25.251558ms
# update_vel: 0.099893ms
# update_pos: 0.089789ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:29 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.726368ms
# reduction_max: 0.715970ms
# reset_init: 0.175933ms
# build: 374.306454ms
# summarize: 18.501947ms
# compute_acc: 25.184786ms
# update_vel: 0.100725ms
# update_pos: 0.090309ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:30 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.727964ms
# reduction_max: 0.732754ms
# reset_init: 0.165831ms
# build: 382.712393ms
# summarize: 24.507041ms
# compute_acc: 25.315726ms
# update_vel: 0.101871ms
# update_pos: 0.083538ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:30 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.677008ms
# reduction_max: 0.687638ms
# reset_init: 0.162808ms
# build: 392.322495ms
# summarize: 18.129237ms
# compute_acc: 26.073432ms
# update_vel: 0.100827ms
# update_pos: 0.084684ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:31 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.683783ms
# reduction_max: 0.697221ms
# reset_init: 0.170308ms
# build: 397.648536ms
# summarize: 18.451425ms
# compute_acc: 25.789682ms
# update_vel: 0.089162ms
# update_pos: 0.082809ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:32 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.757634ms
# reduction_max: 0.751908ms
# reset_init: 0.174474ms
# build: 405.883747ms
# summarize: 20.241937ms
# compute_acc: 27.825621ms
# update_vel: 0.116764ms
# update_pos: 0.100829ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:33 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.787019ms
# reduction_max: 0.794417ms
# reset_init: 0.177287ms
# build: 408.679475ms
# summarize: 22.198093ms
# compute_acc: 26.940307ms
# update_vel: 0.125308ms
# update_pos: 0.102704ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:33 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.781806ms
# reduction_max: 0.789414ms
# reset_init: 0.178122ms
# build: 418.987707ms
# summarize: 28.939029ms
# compute_acc: 28.662496ms
# update_vel: 0.142807ms
# update_pos: 0.119058ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:34 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.802946ms
# reduction_max: 0.800244ms
# reset_init: 0.199162ms
# build: 425.691558ms
# summarize: 25.864537ms
# compute_acc: 29.116350ms
# update_vel: 0.144162ms
# update_pos: 0.128226ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:35 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.837736ms
# reduction_max: 0.855980ms
# reset_init: 0.183953ms
# build: 434.123329ms
# summarize: 24.344327ms
# compute_acc: 28.618225ms
# update_vel: 0.145829ms
# update_pos: 0.127287ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:36 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.816907ms
# reduction_max: 0.819194ms
# reset_init: 1.002287ms
# build: 439.801871ms
# summarize: 23.290689ms
# compute_acc: 29.956557ms
# update_vel: 0.140411ms
# update_pos: 0.132079ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:37 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.900045ms
# reduction_max: 0.887534ms
# reset_init: 0.190830ms
# build: 445.235308ms
# summarize: 27.371215ms
# compute_acc: 28.965619ms
# update_vel: 0.151662ms
# update_pos: 0.128953ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:37 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.803676ms
# reduction_max: 0.809103ms
# reset_init: 0.188744ms
# build: 454.848539ms
# summarize: 29.335895ms
# compute_acc: 28.447390ms
# update_vel: 0.130829ms
# update_pos: 0.118120ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:38 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.918375ms
# reduction_max: 0.895768ms
# reset_init: 1.456246ms
# build: 460.219370ms
# summarize: 31.573505ms
# compute_acc: 29.540204ms
# update_vel: 0.146350ms
# update_pos: 0.133539ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:39 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.864205ms
# reduction_max: 0.888067ms
# reset_init: 0.768539ms
# build: 469.424892ms
# summarize: 26.202258ms
# compute_acc: 29.962390ms
# update_vel: 0.148119ms
# update_pos: 0.128329ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:40 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.828377ms
# reduction_max: 0.832962ms
# reset_init: 0.197182ms
# build: 474.721037ms
# summarize: 27.642039ms
# compute_acc: 29.406245ms
# update_vel: 0.142702ms
# update_pos: 0.118538ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:41 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.855445ms
# reduction_max: 0.858575ms
# reset_init: 0.200101ms
# build: 485.185309ms
# summarize: 31.739439ms
# compute_acc: 30.395933ms
# update_vel: 0.153851ms
# update_pos: 0.140204ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:42 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.944211ms
# reduction_max: 0.973792ms
# reset_init: 0.205828ms
# build: 488.782184ms
# summarize: 34.447148ms
# compute_acc: 30.596976ms
# update_vel: 0.173120ms
# update_pos: 0.155933ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:42 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.903681ms
# reduction_max: 0.897536ms
# reset_init: 0.206141ms
# build: 500.321662ms
# summarize: 32.143396ms
# compute_acc: 32.517392ms
# update_vel: 0.157288ms
# update_pos: 0.152287ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:43 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.846904ms
# reduction_max: 0.851286ms
# reset_init: 0.203434ms
# build: 506.310100ms
# summarize: 31.060055ms
# compute_acc: 31.874265ms
# update_vel: 0.161662ms
# update_pos: 0.142913ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:44 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.833267ms
# reduction_max: 0.845452ms
# reset_init: 0.204370ms
# build: 515.406662ms
# summarize: 33.356938ms
# compute_acc: 31.622078ms
# update_vel: 0.182808ms
# update_pos: 0.153955ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:45 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.856481ms
# reduction_max: 0.865973ms
# reset_init: 0.224370ms
# build: 522.612287ms
# summarize: 37.639340ms
# compute_acc: 34.913847ms
# update_vel: 0.152182ms
# update_pos: 0.135413ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:46 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.785655ms
# reduction_max: 0.792841ms
# reset_init: 0.207702ms
# build: 529.301558ms
# summarize: 31.581008ms
# compute_acc: 33.117600ms
# update_vel: 0.154786ms
# update_pos: 0.127601ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:47 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.912645ms
# reduction_max: 0.923786ms
# reset_init: 0.215100ms
# build: 534.978433ms
# summarize: 33.460688ms
# compute_acc: 32.816350ms
# update_vel: 0.183016ms
# update_pos: 0.156142ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:48 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.941067ms
# reduction_max: 0.948061ms
# reset_init: 0.214475ms
# build: 542.145100ms
# summarize: 33.695374ms
# compute_acc: 36.957287ms
# update_vel: 0.179995ms
# update_pos: 0.156560ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:49 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.899715ms
# reduction_max: 0.900028ms
# reset_init: 0.236974ms
# build: 546.164161ms
# summarize: 36.131111ms
# compute_acc: 41.344997ms
# update_vel: 0.173642ms
# update_pos: 0.158746ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:50 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.906067ms
# reduction_max: 0.894509ms
# reset_init: 0.245933ms
# build: 555.259995ms
# summarize: 34.971823ms
# compute_acc: 47.174473ms
# update_vel: 0.174788ms
# update_pos: 0.150621ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:51 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.941804ms
# reduction_max: 0.939619ms
# reset_init: 0.277912ms
# build: 564.007809ms
# summarize: 39.184646ms
# compute_acc: 42.904891ms
# update_vel: 0.162288ms
# update_pos: 0.152183ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:52 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.865135ms
# reduction_max: 0.877325ms
# reset_init: 0.280098ms
# build: 573.856038ms
# summarize: 31.126727ms
# compute_acc: 43.995829ms
# update_vel: 0.165100ms
# update_pos: 0.146352ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:53 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.944088ms
# reduction_max: 0.931168ms
# reset_init: 0.311766ms
# build: 579.217390ms
# summarize: 34.517874ms
# compute_acc: 46.474684ms
# update_vel: 0.178327ms
# update_pos: 0.166768ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:54 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.970030ms
# reduction_max: 0.973152ms
# reset_init: 0.339786ms
# build: 588.575515ms
# summarize: 40.033290ms
# compute_acc: 45.297601ms
# update_vel: 0.198433ms
# update_pos: 0.175829ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:13:55 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# ...
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.874618ms
# reduction_max: 1.868262ms
# reset_init: 9.400412ms
# build: 3995.413432ms
# summarize: 154.285162ms
# compute_acc: 251.841872ms
# update_vel: 0.801661ms
# update_pos: 0.724371ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:01 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.768468ms
# reduction_max: 1.777518ms
# reset_init: 9.424684ms
# build: 4000.578954ms
# summarize: 152.787038ms
# compute_acc: 252.694267ms
# update_vel: 0.792809ms
# update_pos: 0.719476ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:06 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.767206ms
# reduction_max: 1.752946ms
# reset_init: 9.448330ms
# build: 4010.645309ms
# summarize: 155.845588ms
# compute_acc: 253.869058ms
# update_vel: 0.797807ms
# update_pos: 0.722079ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:11 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.771901ms
# reduction_max: 1.756801ms
# reset_init: 9.477495ms
# build: 4019.282080ms
# summarize: 148.499642ms
# compute_acc: 255.411766ms
# update_vel: 0.796037ms
# update_pos: 0.727913ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:16 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.785021ms
# reduction_max: 1.798873ms
# reset_init: 9.514162ms
# build: 4025.509684ms
# summarize: 156.390785ms
# compute_acc: 255.553017ms
# update_vel: 0.806246ms
# update_pos: 0.731662ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:21 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.784500ms
# reduction_max: 1.784390ms
# reset_init: 9.521453ms
# build: 4025.935725ms
# summarize: 150.710175ms
# compute_acc: 257.101140ms
# update_vel: 0.802912ms
# update_pos: 0.730516ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:26 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.769414ms
# reduction_max: 1.783355ms
# reset_init: 9.555307ms
# build: 4033.770099ms
# summarize: 147.396937ms
# compute_acc: 256.865204ms
# update_vel: 0.800934ms
# update_pos: 0.724372ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:31 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.766594ms
# reduction_max: 1.757327ms
# reset_init: 9.579058ms
# build: 4043.921663ms
# summarize: 149.225695ms
# compute_acc: 257.997493ms
# update_vel: 0.799580ms
# update_pos: 0.733016ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:36 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.758679ms
# reduction_max: 1.763578ms
# reset_init: 9.607181ms
# build: 4045.431662ms
# summarize: 150.400269ms
# compute_acc: 258.479996ms
# update_vel: 0.803017ms
# update_pos: 0.731455ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:41 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.769399ms
# reduction_max: 1.719403ms
# reset_init: 11.380203ms
# build: 4128.186037ms
# summarize: 133.861207ms
# compute_acc: 299.738120ms
# update_vel: 0.821453ms
# update_pos: 0.750829ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:46 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.800446ms
# reduction_max: 1.803775ms
# reset_init: 9.682287ms
# build: 4068.661557ms
# summarize: 144.971108ms
# compute_acc: 258.892391ms
# update_vel: 0.810204ms
# update_pos: 0.733849ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:51 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.889612ms
# reduction_max: 1.894825ms
# reset_init: 9.704370ms
# build: 4070.483536ms
# summarize: 145.120790ms
# compute_acc: 265.054163ms
# update_vel: 0.816663ms
# update_pos: 0.744996ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:29:56 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.797623ms
# reduction_max: 1.796798ms
# reset_init: 9.728433ms
# build: 4078.514577ms
# summarize: 145.833711ms
# compute_acc: 263.139892ms
# update_vel: 0.813017ms
# update_pos: 0.736663ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:01 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.900662ms
# reduction_max: 1.892222ms
# reset_init: 9.808747ms
# build: 4085.941559ms
# summarize: 149.507141ms
# compute_acc: 261.047912ms
# update_vel: 0.817703ms
# update_pos: 0.741662ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:06 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.776067ms
# reduction_max: 1.779512ms
# reset_init: 9.783952ms
# build: 4087.904891ms
# summarize: 148.964027ms
# compute_acc: 261.718746ms
# update_vel: 0.813850ms
# update_pos: 0.738017ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:11 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.776177ms
# reduction_max: 1.790651ms
# reset_init: 9.802808ms
# build: 4099.462184ms
# summarize: 151.297574ms
# compute_acc: 265.179163ms
# update_vel: 0.812807ms
# update_pos: 0.743433ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:16 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.861568ms
# reduction_max: 1.865749ms
# reset_init: 9.833849ms
# build: 4101.607184ms
# summarize: 154.392772ms
# compute_acc: 263.369473ms
# update_vel: 0.824476ms
# update_pos: 0.751663ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:21 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.777002ms
# reduction_max: 1.768876ms
# reset_init: 9.854995ms
# build: 4113.209787ms
# summarize: 143.086314ms
# compute_acc: 266.923224ms
# update_vel: 0.821454ms
# update_pos: 0.741663ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:26 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.777014ms
# reduction_max: 1.781698ms
# reset_init: 9.877704ms
# build: 4115.630099ms
# summarize: 141.477453ms
# compute_acc: 265.238224ms
# update_vel: 0.820931ms
# update_pos: 0.751871ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:31 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.821801ms
# reduction_max: 1.795139ms
# reset_init: 10.922913ms
# build: 4121.601141ms
# summarize: 143.128812ms
# compute_acc: 264.431976ms
# update_vel: 0.820933ms
# update_pos: 0.748329ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:36 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.786806ms
# reduction_max: 1.808880ms
# reset_init: 9.943432ms
# build: 4134.570308ms
# summarize: 143.751720ms
# compute_acc: 269.009579ms
# update_vel: 0.823121ms
# update_pos: 0.747287ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:41 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.833658ms
# reduction_max: 1.804195ms
# reset_init: 9.975100ms
# build: 4142.240098ms
# summarize: 151.163707ms
# compute_acc: 267.309890ms
# update_vel: 0.833641ms
# update_pos: 0.758016ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:46 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.797318ms
# reduction_max: 1.804716ms
# reset_init: 9.996349ms
# build: 4144.788329ms
# summarize: 154.170261ms
# compute_acc: 267.685100ms
# update_vel: 0.826039ms
# update_pos: 0.755724ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:51 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.930027ms
# reduction_max: 1.922214ms
# reset_init: 10.024267ms
# build: 4153.730778ms
# summarize: 152.381725ms
# compute_acc: 269.938642ms
# update_vel: 0.835933ms
# update_pos: 0.757600ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:30:56 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.915350ms
# reduction_max: 1.923366ms
# reset_init: 10.045202ms
# build: 4157.623744ms
# summarize: 159.676727ms
# compute_acc: 270.300621ms
# update_vel: 0.839163ms
# update_pos: 0.765309ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:31:01 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.942423ms
# reduction_max: 1.927733ms
# reset_init: 10.104579ms
# build: 4162.534788ms
# summarize: 154.324013ms
# compute_acc: 270.743744ms
# update_vel: 0.849058ms
# update_pos: 0.772599ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:31:06 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.807943ms
# reduction_max: 1.812427ms
# reset_init: 10.102183ms
# build: 4173.736661ms
# summarize: 152.179441ms
# compute_acc: 271.666039ms
# update_vel: 0.836766ms
# update_pos: 0.759786ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:31:11 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.908576ms
# reduction_max: 1.910029ms
# reset_init: 10.154163ms
# build: 4176.289371ms
# summarize: 155.293390ms
# compute_acc: 275.284683ms
# update_vel: 0.844786ms
# update_pos: 0.770413ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:31:16 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.915134ms
# reduction_max: 1.920761ms
# reset_init: 10.158017ms
# build: 4183.314058ms
# summarize: 152.846111ms
# compute_acc: 272.774684ms
# update_vel: 0.843642ms
# update_pos: 0.769893ms
# number of platforms: 1
# selected platform 0: Intel(R) OpenCL Graphics
# number of devices: 1
# selected device 0: Intel(R) Arc(TM) Graphics
# compiling:
# // Tue Jul 28 12:31:21 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 1.938888ms
# reduction_max: 1.938987ms
# reset_init: 10.197599ms
# build: 4193.646870ms
# summarize: 158.017455ms
# compute_acc: 273.860412ms
# update_vel: 0.845828ms
# update_pos: 0.770827ms

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())

plt.plot(X, Y)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600 theta = 0.1",
            "AMD RX6600 theta = 0.5",
            "Intel Arc theta = 0.1",
            "Intel Arc theta = 0.5"])
plt.savefig("./images/BH.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))

plt.plot(X, Y)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dell'accelerazione, algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600 theta = 0.1",
            "AMD RX6600 theta = 0.5",
            "Intel Arc theta = 0.1",
            "Intel Arc theta = 0.5"])
plt.savefig("./images/BH_acc_time.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[3]))
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[3]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[3]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[3]))

plt.plot(X, Y)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di costruzione del quadtree seriale, algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600 theta = 0.1",
            "AMD RX6600 theta = 0.5",
            "Intel Arc theta = 0.1",
            "Intel Arc theta = 0.5"])
plt.savefig("./images/BH.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))

plt.plot(X, Y)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di summarize tree, algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600 theta = 0.1",
            "AMD RX6600 theta = 0.5",
            "Intel Arc theta = 0.1",
            "Intel Arc theta = 0.5"])
plt.savefig("./images/BH.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[0:8], dtype=float).sum())


plt.plot(X, Y)
plt.grid(alpha=0.4)

testname = "180ksweep_naive_integratalaptop"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2])) 
            
plt.plot(X, Y)

testname = "180ksweep_naive_rx6600"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
    
    
plt.plot(X[:450], Y[:450])


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo dei kernel di riduzione algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600"])
plt.savefig("./images/BH-reduction.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[0:2], dtype=float).sum())


plt.plot(X, Y)
plt.grid(alpha=0.4)


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo dei kernel di riduzione algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600"])
plt.savefig("./images/BH-reduction.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"



X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[0]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[0]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni Intel Arc",
            "calcolo posizioni AMD RX6600", 
            "calcolo posizioni AMD raphael"])
plt.savefig("./images/naive_position_manygpu.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"



X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[1]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[1]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[1]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo velocità Intel Arc",
            "calcolo velocità AMD RX6600", 
            "calcolo velocità AMD raphael"])
plt.savefig("./images/naive_speed_manygpu.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[2]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[2]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[2]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc",
            "calcolo accelerazione AMD RX6600", 
            "calcolo accelerazione AMD raphael"])
plt.savefig("./images/naive_acc_manygpu.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[2]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[2]))

plt.plot(X, Y1[:450])

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc",
            "calcolo accelerazione AMD RX6600"])
plt.savefig("./images/naive_acc_manygpu_no_raphael.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[2]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[2]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[2]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc",
            "calcolo accelerazione AMD RX6600", 
            "calcolo accelerazione AMD raphael"])
plt.savefig("./images/naive_linear_kernel_manygpu_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))
        Y1.append(float(d[1]))

plt.plot(X, Y0)
plt.plot(X, Y1)
plt.grid(alpha=0.4)

testname = "180ksweep_naive_rx6600"
Y3 = []
Y4 = []
Y5 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y3.append(float(d[0]))
        Y4.append(float(d[1]))

plt.plot(X, Y3)
plt.plot(X, Y4)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni Intel Arc", "calcolo velocità Intel Arc", 
            "calcolo posizioni AMD RX6600", "calcolo velocità AMD RX6600"])
plt.savefig("./images/naive_linear_kernel_manygpu_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y2.append(float(d[2]))

plt.plot(X, Y2)
plt.grid(alpha=0.4)

testname = "180ksweep_naive_rx6600"
Y3 = []
Y4 = []
Y5 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y5.append(float(d[2]))

plt.plot(X, Y5)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc", "calcolo accelerazione AMD RX6600"])
plt.savefig("./images/naive_acc_update_kernel_manygpu_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))
        Y1.append(float(d[1]))
        Y2.append(float(d[2]))

plt.plot(X, Y0)
plt.plot(X, Y1)
plt.plot(X, Y2)
plt.grid(alpha=0.4)
plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni", "calcolo velocità", "calcolo accelerazione"])
plt.savefig("./images/naive_kernel_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))
        Y1.append(float(d[1]))
        Y2.append(float(d[2]))

plt.plot(X, Y0)
plt.plot(X, Y1)
#plt.plot(X, Y2)
plt.grid(alpha=0.4)
plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni", "calcolo velocità"])
plt.savefig("./images/naive_kernel_noacc_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
        if float(d[0]) + float(d[1]) + float(d[2]) > 166.66:
                            print(int(d[3]) - 400)  
            
plt.plot(X, Y)

testname = "180ksweep_naive_rx6600"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
    
        

plt.plot(X[:450], Y[:450])


testname = "180ksweep_naive_amd_raphael"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))


plt.plot(X[:450], Y[:450])

plt.hlines(333.33, 0, 80000, linestyles='--', colors='black')
plt.hlines(166.66, 0, 80000, linestyles='--', colors='grey')

plt.xlim(0, 80000)
plt.ylim(0, 500)
plt.grid(alpha=0.4)


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo algoritmo naive (10 iterazioni)")
plt.legend()
plt.legend(["Intel Arc",
            "AMD RX6600", 
            "AMD raphael",
            '30 FPS',
            '60 FPS'])
plt.savefig("./images/naive_total_ms.pdf")
plt.show()
# Out:
# 34410
# 35610
# 36010
# 36410
# 36810
# 37210
# 37610
# 38010
# 38410
# 38810
# 39210
# 39610
# 40010
# 40410
# 40810
# 41210
# 41610
# 42010
# 42410
# 42810
# 43210
# 43610
# 44010
# 44410
# 44810
# 45210
# 45610
# 46010
# 46410
# 46810
# 47210
# 47610
# 48010
# 48410
# 48810
# 49210
# 49610
# 50010
# 50410
# 50810
# 51210
# 51610
# 52010
# 52410
# 52810
# 53210
# 53610
# 54010
# 54410
# 54810
# 55210
# 55610
# 56010
# 56410
# 56810
# 57210
# 57610
# 58010
# 58410
# 58810
# 59210
# 59610
# 60010
# 60410
# 60810
# 61210
# 61610
# 62010
# 62410
# 62810
# 63210
# 63610
# 64010
# 64410
# 64810
# 65210
# 65610
# 66010
# 66410
# 66810
# 67210
# 67610
# 68010
# 68410
# 68810
# 69210
# 69610
# 70010
# 70410
# 70810
# 71210
# 71610
# 72010
# 72410
# 72810
# 73210
# 73610
# 74010
# 74410
# 74810
# 75210
# 75610
# 76010
# 76410
# 76810
# 77210
# 77610
# 78010
# 78410
# 78810
# 79210
# 79610
# 80010
# 80410
# 80810
# 81210
# 81610
# 82010
# 82410
# 82810
# 83210
# 83610
# 84010
# 84410
# 84810
# 85210
# 85610
# 86010
# 86410
# 86810
# 87210
# 87610
# 88010
# 88410
# 88810
# 89210
# 89610
# 90010
# 90410
# 90810
# 91210
# 91610
# 92010
# 92410
# 92810
# 93210
# 93610
# 94010
# 94410
# 94810
# 95210
# 95610
# 96010
# 96410
# 96810
# 97210
# 97610
# 98010
# 98410
# 98810
# 99210
# 99610
# 100010
# 100410
# 100810
# 101210
# 101610
# 102010
# 102410
# 102810
# 103210
# 103610
# 104010
# 104410
# 104810
# 105210
# 105610
# 106010
# 106410
# 106810
# 107210
# 107610
# 108010
# 108410
# 108810
# 109210
# 109610
# 110010
# 110410
# 110810
# 111210
# 111610
# 112010
# 112410
# 112810
# 113210
# 113610
# 114010
# 114410
# 114810
# 115210
# 115610
# 116010
# 116410
# 116810
# 117210
# 117610
# 118010
# 118410
# 118810
# 119210
# 119610
# 120010
# 120410
# 120810
# 121210
# 121610
# 122010
# 122410
# 122810
# 123210
# 123610
# 124010
# 124410
# 124810
# 125210
# 125610
# 126010
# 126410
# 126810
# 127210
# 127610
# 128010
# 128410
# 128810
# 129210
# 129610
# 130010
# 130410
# 130810
# 131210
# 131610
# 132010
# 132410
# 132810
# 133210
# 133610
# 134010
# 134410
# 134810
# 135210
# 135610
# 136010
# 136410
# 136810
# 137210
# 137610
# 138010
# 138410
# 138810
# 139210
# 139610
# 140010
# 140410
# 140810
# 141210
# 141610
# 142010
# 142410
# 142810
# 143210
# 143610
# 144010
# 144410
# 144810
# 145210
# 145610
# 146010
# 146410
# 146810
# 147210
# 147610
# 148010
# 148410
# 148810
# 149210
# 149610
# 150010
# 150410
# 150810
# 151210
# 151610
# 152010
# 152410
# 152810
# 153210
# 153610
# 154010
# 154410
# 154810
# 155210
# 155610
# 156010
# 156410
# 156810
# 157210
# 157610
# 158010
# 158410
# 158810
# 159210
# 159610
# 160010
# 160410
# 160810
# 161210
# 161610
# 162010
# 162410
# 162810
# 163210
# 163610
# 164010
# 164410
# 164810
# 165210
# 165610
# 166010
# 166410
# 166810
# 167210
# 167610
# 168010
# 168410
# 168810
# 169210
# 169610
# 170010
# 170410
# 170810
# 171210
# 171610
# 172010
# 172410
# 172810
# 173210
# 173610
# 174010
# 174410
# 174810
# 175210
# 175610
# 176010
# 176410
# 176810
# 177210
# 177610
# 178010
# 178410
# 178810
# 179210
# /tmp/ipykernel_4278/1074556334.py:57: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_rx6600"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
    
        

plt.plot(X[:450], Y[:450])


testname = "180ksweep_naive_rx6600_restrict"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))


plt.plot(X[:450], Y[:450])

#plt.hlines(333.33, 0, 80000, linestyles='--', colors='black')
#plt.hlines(166.66, 0, 80000, linestyles='--', colors='grey')

#plt.xlim(0, 80000)
#plt.ylim(0, 500)
plt.grid(alpha=0.4)


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo algoritmo naive (10 iterazioni)")
plt.legend(["AMD RX6600 no restrict",
            "AMD RX6600 with restrict"])
plt.savefig("./images/norestrict_vs_restrict_ms.pdf")
plt.show()
