# %%
import csv
from subprocess import run
import os
for c in [0.5]:
    for b in range(10, 180000, 400):
        run(['./barnes_hut_cpu.out', f'{b}', '10', 'galactic_chaos_180k.csv', f'TEST{str(c).replace(".", "_")}', f'{c}', '0'])
# Out:
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:55 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.073641ms
# reduction_max: 0.071682ms
# reset_init: 0.018640ms
# build + map + unmap: 0.588979ms
# summarize: 0.729853ms
# compute_acc: 0.130482ms
# update_vel: 0.017720ms
# update_pos: 0.018041ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:56 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.161202ms
# reduction_max: 0.153764ms
# reset_init: 0.016640ms
# build + map + unmap: 1.217363ms
# summarize: 0.910011ms
# compute_acc: 1.456263ms
# update_vel: 0.018720ms
# update_pos: 0.016721ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:56 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.179924ms
# reduction_max: 0.171166ms
# reset_init: 0.017320ms
# build + map + unmap: 1.491476ms
# summarize: 0.934995ms
# compute_acc: 1.529164ms
# update_vel: 0.017840ms
# update_pos: 0.018480ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:56 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.196556ms
# reduction_max: 0.187515ms
# reset_init: 0.019280ms
# build + map + unmap: 2.151829ms
# summarize: 1.151782ms
# compute_acc: 1.739807ms
# update_vel: 0.017920ms
# update_pos: 0.016760ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:57 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.195162ms
# reduction_max: 0.189681ms
# reset_init: 0.019922ms
# build + map + unmap: 2.492732ms
# summarize: 1.128498ms
# compute_acc: 1.967752ms
# update_vel: 0.018201ms
# update_pos: 0.276164ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:57 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.196323ms
# reduction_max: 0.189565ms
# reset_init: 0.023440ms
# build + map + unmap: 3.563496ms
# summarize: 1.171976ms
# compute_acc: 2.163078ms
# update_vel: 0.019720ms
# update_pos: 0.017201ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:57 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.214489ms
# reduction_max: 0.206887ms
# reset_init: 0.023961ms
# build + map + unmap: 4.147226ms
# summarize: 1.222345ms
# compute_acc: 2.488593ms
# update_vel: 0.021400ms
# update_pos: 0.017600ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:58 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.209602ms
# reduction_max: 0.213883ms
# reset_init: 0.023841ms
# build + map + unmap: 4.763963ms
# summarize: 1.235541ms
# compute_acc: 2.361800ms
# update_vel: 0.022441ms
# update_pos: 0.017520ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:58 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.212042ms
# reduction_max: 0.205603ms
# reset_init: 0.024120ms
# build + map + unmap: 5.751489ms
# summarize: 1.279741ms
# compute_acc: 2.673564ms
# update_vel: 0.022480ms
# update_pos: 0.017640ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:58 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.212524ms
# reduction_max: 0.206962ms
# reset_init: 0.025961ms
# build + map + unmap: 6.247939ms
# summarize: 1.369141ms
# compute_acc: 2.870449ms
# update_vel: 0.024360ms
# update_pos: 0.018280ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:59 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.208722ms
# reduction_max: 0.205642ms
# reset_init: 0.029040ms
# build + map + unmap: 7.105719ms
# summarize: 1.464584ms
# compute_acc: 2.944887ms
# update_vel: 0.023721ms
# update_pos: 0.018440ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:59 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.226044ms
# reduction_max: 0.224803ms
# reset_init: 0.032041ms
# build + map + unmap: 6.536514ms
# summarize: 2.044037ms
# compute_acc: 2.682526ms
# update_vel: 0.020080ms
# update_pos: 0.017760ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:44:59 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.225608ms
# reduction_max: 0.228844ms
# reset_init: 0.028280ms
# build + map + unmap: 7.123346ms
# summarize: 1.497428ms
# compute_acc: 2.755167ms
# update_vel: 0.019320ms
# update_pos: 0.018040ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:45:00 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.235484ms
# reduction_max: 0.225207ms
# reset_init: 0.036600ms
# build + map + unmap: 8.781482ms
# summarize: 1.523068ms
# compute_acc: 3.055609ms
# update_vel: 0.022680ms
# update_pos: 0.019920ms
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Mon Aug 17 16:45:00 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# warning: argument unused during compilation: '-I .' [-Wunused-command-line-argument]
# 1 warning generated.
#
# =========
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# TIMES:
#
# reduction_min: 0.231841ms
# reduction_max: 0.226003ms
# reset_init: 0.039281ms
# build + map + unmap: 9.110770ms
# summarize: 1.621913ms
# compute_acc: 3.171497ms
# update_vel: 0.022880ms
# update_pos: 0.019802ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       2 from subprocess import run
#       3 import os
#       4 for c in [0.5]:
#       5     for b in range(10, 180000, 400):
# ----> 6         run(['./barnes_hut_cpu.out', f'{b}', '10', 'galactic_chaos_180k.csv', f'TEST{str(c).replace(".", "_")}', f'{c}', '0'])
#
# File /usr/lib64/python3.13/subprocess.py:556, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
# --> 556         stdout, stderr = process.communicate(input, timeout=timeout)
#     557     except TimeoutExpired as exc:
#     558         process.kill()
#
# File /usr/lib64/python3.13/subprocess.py:1214, in Popen.communicate(self, input, timeout)
#    1212         stderr = self.stderr.read()
#    1213         self.stderr.close()
# -> 1214     self.wait()
#    1215 else:
#    1216     if timeout is not None:
#
# File /usr/lib64/python3.13/subprocess.py:1280, in Popen.wait(self, timeout)
#    1278     endtime = _time() + timeout
#    1279 try:
# -> 1280     return self._wait(timeout=timeout)
#    1281 except KeyboardInterrupt:
#    1282     # https://bugs.python.org/issue25942
#    1283     # The first keyboard interrupt waits briefly for the child to
#    1284     # exit under the common assumption that it also received the ^C
#    1285     # generated SIGINT and will exit rapidly.
#    1286     if timeout is not None:
#
# File /usr/lib64/python3.13/subprocess.py:2085, in Popen._wait(self, timeout)
#    2083 if self.returncode is not None:
#    2084     break  # Another thread waited.
# -> 2085 (pid, sts) = self._try_wait(0)
#    2086 # Check the pid and loop as waitpid has been known to
#    2087 # return 0 even without WNOHANG in odd situations.
#    2088 # http://bugs.python.org/issue14396.
#    2089 if pid == self.pid:
#
# File /usr/lib64/python3.13/subprocess.py:2043, in Popen._try_wait(self, wait_flags)
#    2041 """All callers to this function MUST hold self._waitpid_lock."""
#    2042 try:
# -> 2043     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2044 except ChildProcessError:
#    2045     # This happens if SIGCLD is set to be ignored or waiting
#    2046     # for child processes has otherwise been disabled for our
#    2047     # process.  This child is dead, we can't get the status.
#    2048     pid = self.pid
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[:8], dtype=float).sum())

plt.plot(X, Y)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600 theta = 0.1",
            "AMD RX6600 theta = 0.5",
            "Intel Arc theta = 0.1",
            "Intel Arc theta = 0.5"])
plt.savefig("./images/BH.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))

plt.plot(X, Y)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dell'accelerazione, algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600 theta = 0.1",
            "AMD RX6600 theta = 0.5",
            "Intel Arc theta = 0.1",
            "Intel Arc theta = 0.5"])
plt.savefig("./images/BH_acc_time.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[3]))
plt.plot(X, Y)


testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[3]))
plt.plot(X, Y)

plt.grid(alpha=0.6)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di costruzione del quadtree seriale, algoritmo Barnes-Hut (10 iterazioni)")
plt.legend([r"AMD RX6600",
            r"Intel Arc"])
plt.savefig("./images/bh_build_quadtree.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[4]))

plt.plot(X, Y)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di summarize tree, algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600 theta = 0.1",
            "AMD RX6600 theta = 0.5",
            "Intel Arc theta = 0.1",
            "Intel Arc theta = 0.5"])
plt.savefig("./images/BH.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[0:8], dtype=float).sum())


plt.plot(X, Y)
plt.grid(alpha=0.4)

testname = "180ksweep_naive_integratalaptop"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2])) 
            
plt.plot(X, Y)

testname = "180ksweep_naive_rx6600"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
    
    
plt.plot(X[:450], Y[:450])


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo dei kernel di riduzione algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600"])
plt.savefig("./images/BH-reduction.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.array(d[0:2], dtype=float).sum())


plt.plot(X, Y)
plt.grid(alpha=0.4)


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo dei kernel di riduzione algoritmo Barnes-Hut (10 iterazioni)")
plt.legend(["AMD RX6600"])
plt.savefig("./images/BH-reduction.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"



X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[0]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[0]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni Intel Arc",
            "calcolo posizioni AMD RX6600", 
            "calcolo posizioni AMD raphael"])
plt.savefig("./images/naive_position_manygpu.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"



X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[1]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[1]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[1]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo velocità Intel Arc",
            "calcolo velocità AMD RX6600", 
            "calcolo velocità AMD raphael"])
plt.savefig("./images/naive_speed_manygpu.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[2]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[2]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[2]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc",
            "calcolo accelerazione AMD RX6600", 
            "calcolo accelerazione AMD raphael"])
plt.savefig("./images/naive_acc_manygpu.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[2]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[2]))

plt.plot(X, Y1[:450])

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc",
            "calcolo accelerazione AMD RX6600"])
plt.savefig("./images/naive_acc_manygpu_no_raphael.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[2]))

plt.plot(X, Y0)
Y1 = []
testname = "180ksweep_naive_rx6600"

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y1.append(float(d[2]))

plt.plot(X, Y1[:450])


testname = "180ksweep_naive_amd_raphael"
Y2 = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y2.append(float(d[2]))

plt.plot(X, Y2)

plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc",
            "calcolo accelerazione AMD RX6600", 
            "calcolo accelerazione AMD raphael"])
plt.savefig("./images/naive_linear_kernel_manygpu_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))
        Y1.append(float(d[1]))

plt.plot(X, Y0)
plt.plot(X, Y1)
plt.grid(alpha=0.4)

testname = "180ksweep_naive_rx6600"
Y3 = []
Y4 = []
Y5 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y3.append(float(d[0]))
        Y4.append(float(d[1]))

plt.plot(X, Y3)
plt.plot(X, Y4)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni Intel Arc", "calcolo velocità Intel Arc", 
            "calcolo posizioni AMD RX6600", "calcolo velocità AMD RX6600"])
plt.savefig("./images/naive_linear_kernel_manygpu_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y2.append(float(d[2]))

plt.plot(X, Y2)
plt.grid(alpha=0.4)

testname = "180ksweep_naive_rx6600"
Y3 = []
Y4 = []
Y5 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        Y5.append(float(d[2]))

plt.plot(X, Y5)
plt.grid(alpha=0.4)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo accelerazione Intel Arc", "calcolo accelerazione AMD RX6600"])
plt.savefig("./images/naive_acc_update_kernel_manygpu_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))
        Y1.append(float(d[1]))
        Y2.append(float(d[2]))

plt.plot(X, Y0)
plt.plot(X, Y1)
plt.plot(X, Y2)
plt.grid(alpha=0.4)
plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni", "calcolo velocità", "calcolo accelerazione"])
plt.savefig("./images/naive_kernel_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y0 = []
Y1 = []
Y2 = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y0.append(float(d[0]))
        Y1.append(float(d[1]))
        Y2.append(float(d[2]))

plt.plot(X, Y0)
plt.plot(X, Y1)
#plt.plot(X, Y2)
plt.grid(alpha=0.4)
plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo dei kernel nell'algoritmo naive (10 iterazioni)")
plt.legend(["calcolo posizioni", "calcolo velocità"])
plt.savefig("./images/naive_kernel_noacc_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
        if float(d[0]) + float(d[1]) + float(d[2]) > 166.66:
                            print(int(d[3]) - 400)  
            
plt.plot(X, Y)

testname = "180ksweep_naive_rx6600"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
    
        

plt.plot(X[:450], Y[:450])


testname = "180ksweep_naive_amd_raphael"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))


plt.plot(X[:450], Y[:450])

plt.hlines(333.33, 0, 80000, linestyles='--', colors='black')
plt.hlines(166.66, 0, 80000, linestyles='--', colors='grey')

plt.xlim(0, 80000)
plt.ylim(0, 500)
plt.grid(alpha=0.4)


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo algoritmo naive (10 iterazioni)")
plt.legend()
plt.legend(["Intel Arc",
            "AMD RX6600", 
            "AMD raphael",
            '30 FPS',
            '60 FPS'])
plt.savefig("./images/naive_total_ms.pdf")
plt.show()
# Out:
# 34410
# 35610
# 36010
# 36410
# 36810
# 37210
# 37610
# 38010
# 38410
# 38810
# 39210
# 39610
# 40010
# 40410
# 40810
# 41210
# 41610
# 42010
# 42410
# 42810
# 43210
# 43610
# 44010
# 44410
# 44810
# 45210
# 45610
# 46010
# 46410
# 46810
# 47210
# 47610
# 48010
# 48410
# 48810
# 49210
# 49610
# 50010
# 50410
# 50810
# 51210
# 51610
# 52010
py:57: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_integratalaptop"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
            
plt.plot(X, Y, label="Intel Arc naive")

testname = "180ksweep_naive_rx6600"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
    
        

plt.plot(X[:450], Y[:450], label="AMD RX6600 naive")


testname = "180ksweep_naive_amd_raphael"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))


plt.plot(X[:450], Y[:450], label="AMD Raphael naive")

testname = "180ksweep_BH_intel_arc_0_5"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.sum(np.array(d[0:8], dtype=float)))


plt.plot(X[:450], Y[:450], label=r"Intel Arc pure BH $\theta$=0.5")

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.sum(np.array(d[0:8], dtype=float)))


plt.plot(X[:450], Y[:450], label=r"AMD RX6600 pure BH $\theta$=0.5")

testname = "180ksweep_BHCPU_intel_arc_0_5"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.sum(np.array(d[0:8], dtype=float)))


plt.plot(X[:450], Y[:450], label=r"Intel Arc hybrid BH $\theta$=0.5")


testname = "180ksweep_BHCPU_rx6600_0_5"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(np.sum(np.array(d[0:8], dtype=float)))


plt.plot(X[:450], Y[:450], label=r"AMD RX6600 hybrid BH $\theta$=0.5")

plt.hlines(333.33, 0, 80000, linestyles='--', colors='black')
plt.hlines(166.66, 0, 80000, linestyles='--', colors='grey')

plt.xlim(0, 80000)
plt.ylim(0, 500)
plt.grid(alpha=0.4)


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo vari algoritmi (10 iterazioni)")
plt.legend()
plt.savefig("./images/naive_bh_total_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

testname = "180ksweep_naive_rx6600"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))
    
        

plt.plot(X[:450], Y[:450])


testname = "180ksweep_naive_rx6600_restrict"
X = []
Y = []

with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[0]) + float(d[1]) + float(d[2]))


plt.plot(X[:450], Y[:450])

#plt.hlines(333.33, 0, 80000, linestyles='--', colors='black')
#plt.hlines(166.66, 0, 80000, linestyles='--', colors='grey')

#plt.xlim(0, 80000)
#plt.ylim(0, 500)
plt.grid(alpha=0.4)


plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo algoritmo naive (10 iterazioni)")
plt.legend(["AMD RX6600 no restrict",
            "AMD RX6600 with restrict"])
plt.savefig("./images/norestrict_vs_restrict_ms.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
testname = "180ksweep_BH_rx6600_0_1"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_rx6600_0_5"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_1"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_BH_intel_arc_0_5"

X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[8]))
        Y.append(float(d[5]))
plt.plot(X, Y)

testname = "180ksweep_naive_rx6600"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[2]))

plt.plot(X, Y)


testname = "180ksweep_naive_integratalaptop"
X = []
Y = []
with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
    reader = csv.reader(csvfile)
    for d in reader:
        X.append(int(d[3]))
        Y.append(float(d[2]))
plt.plot(X, Y)

plt.grid(alpha=0.6)

plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.title("tempo di calcolo accelerazione Barnes-Hut vs naive (10 iterazioni)")
plt.legend([r"BH AMD RX6600 $\theta$ = 0.1",
            r"BH AMD RX6600 $\theta$ = 0.5",
            r"BH Intel Arc $\theta$ = 0.1",
            r"BH Intel Arc $\theta$ = 0.5",
            "naive AMD RX6600",
            "naive Intel Arc"])
plt.savefig("./images/bh_vs_naive_acc.pdf")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
testname = "180ksweep_BH_rx6600_0_1"


for i in [0,1,2,6,7]:
    X = []
    Y = []
    with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
        reader = csv.reader(csvfile)
        for d in reader:
            X.append(int(d[8]))
            Y.append(float(d[i]))
    plt.plot(X, Y)
plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.legend([
    "reduction_min",
    "reduction_max",
    "reset_init",
    "update_vel",
    "update_pos"
    ])
plt.title(r"tempo di dei vari kernel Barnes-Hut (10 iterazioni, $\theta = 0.1$), pt.1")
plt.grid(alpha=0.6)
plt.savefig("./images/bh_kernel_comparison_theta0_1.pdf")

# %%
for i in [3,4,5]:
    X = []
    Y = []
    with open(f"tests/{testname}/{testname}.csv", 'r') as csvfile:
        reader = csv.reader(csvfile)
        for d in reader:
            X.append(int(d[8]))
            Y.append(float(d[i]))
    plt.plot(X, Y)
plt.xlabel("numero di corpi")
plt.ylabel("tempo in ms")
plt.legend(["build",
    "summarize",
    "compute_acc"])
plt.title(r"tempo di dei vari kernel Barnes-Hut (10 iterazioni, $\theta = 0.1$), pt.2")
plt.grid(alpha=0.6)
plt.savefig("./images/bh_kernel_comparison_theta0_1pt2.pdf")
