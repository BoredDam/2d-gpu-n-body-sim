# %%
import csv
from subprocess import run
import os
c = 0.5
for lws in [1]:
    run(['./barnes_hut_for_testing_v2.out', '179600', '10', 'galactic_chaos_180k.csv', f'SLIDING_WINDOW{str(c).replace(".", "_")}', f'{c}', '0', f'{256 * lws}', '4'])
# Out:
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Wed Aug 26 14:23:13 2026
# #include "src/kernels/barnes_hut_v2.ocl"
# === BUILD LOG ===
# ...
# 1 warning generated.
#
# ...
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# 4 wg per CU, 14 CU = 64 work-groups
# bounding box:
# min = (-950.304871, -944.868652)
# max = (955.722168, 943.344604)
# TIMES:
#
# reduction_k1: 0.077400ms
# reduction_k2: 0.030080ms
# reset_init: 1.924438ms
# build: 4112.618156ms
# summarize: 22.970062ms
# compute_acc: 191.959650ms
# update_vel: 0.209680ms
# update_pos: 0.070360ms

# %%
import csv
from subprocess import run
import os
for lws in [1]:
    run(['./barnes_hut_for_testing.out', '179600', '10', 'galactic_chaos_180k.csv', f'PARALLEL_REDUCTION{str(c).replace(".", "_")}', f'{c}', '0'])
# Out:
# number of platforms: 1
# selected platform 0: AMD Accelerated Parallel Processing
# number of devices: 2
# selected device 0: gfx1032
# compiling:
# // Wed Aug 26 14:23:21 2026
# #include "src/kernels/barnes_hut.ocl"
# === BUILD LOG ===
# ...
# 1 warning generated.
#
# ...
# looking for ./galaxies/galactic_chaos_180k.csv...
# file opened succesfully
# file closed succesfully.
# bounding box:
# min = (-950.304871, -944.868652)
# max = (955.722168, 943.344604)
# TIMES:
#
# reduction_min: 0.389960ms
# reduction_max: 0.383600ms
# reset_init: 1.987040ms
# build: 4116.486043ms
# summarize: 22.889153ms
# compute_acc: 192.896816ms
# update_vel: 0.205680ms
# update_pos: 0.070039ms
